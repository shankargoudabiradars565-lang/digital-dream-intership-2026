# %% [markdown]
# <a href="https://colab.research.google.com/github/shankargoudabiradars565-lang/digital-dream-intership-2026/blob/main/week-3-fashion-mnist-cnn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# In the videos you looked at how you would improve Fashion MNIST using Convolutions. For your exercise see if you can improve MNIST to 99.8% accuracy or more using only a single convolutional layer and a single MaxPooling 2D. You should stop training once the accuracy goes above this amount. It should happen in less than 20 epochs, so it's ok to hard code the number of epochs for training, but your training must end once it hits the above metric. If it doesn't, then you'll need to redesign your layers.
#
# I've started the code for you -- you need to finish it!
#
# When 99.8% accuracy has been hit, you should print out the string "Reached 99.8% accuracy so cancelling training!"

# %%
#online order summary generator
prices=[1200,550,300,900,150]
total_value=sum(prices)
average_price=total_value/len(prices)
print("total order:",total_value)
print("average price:",average_price)
# Out:
# total order: 3100
# average price: 620.0

# %%
#product category tracker
products={"laptop":"electronics","chair":"furniture","mobile":"electronics"}
print("product names:",list(products.keys()))
print("categories:",list(products.values()))
print("total products:",len(products))
# Out:
# product names: ['laptop', 'chair', 'mobile']
# categories: ['electronics', 'furniture', 'electronics']
# total products: 3

# %%
#website traffic analysis
visitors=[120,200,150,180,220,170,160]
print("heighest traffic:",max(visitors))
print("lowest traffic:",min(visitors))
# Out:
# heighest traffic: 220
# lowest traffic: 120

# %%
#customer purchase validation
amount=float(input("enter purchase amount:"))
if amount>0:
    print("valid purchase")
else:
    print("invlaid purchase")
# Out:
# enter purchase amount:200
# valid purchase

# %%
#inventory stock comparison
opening=[50,40,60]
closing=[45,45,55]
for i in range(len(opening)):
    if closing[i]>opening[i]:
        print("product",i+1,"stock increased")
    elif closing[i]<opening[i]:
        print("product",i+1,"stock decreased")
    else:
        print("product", i+1,"stock same")
# Out:
# product 1 stock decreased
# product 2 stock increased
# product 3 stock decreased

# %%
#student course mapping
students={
    "Asha":"python",
    "ravi":"data analytics",
    "neha":"ai"}
print("students",list(students.keys()))
print("courses:",list(students.values()))
name=input("enter student name:")
if name in students:
    print("students exists")
else:
    print("students not found")
# Out:
# students ['Asha', 'ravi', 'neha']
# courses: ['python', 'data analytics', 'ai']
# enter student name:Asha
# students exists

# %%
#delivery distance categorized
distance=int(input("enter distance:"))
if distance<=5:
    print("local delivery")
elif distance<=20:
    print("city delivery")
else:
    print("outstation delivery")
# Out:
# enter distance:25
# outstation delivery

# %%
#online exam score analyzer
scores=[65,78,80,55,90]
total=sum(scores)
average=total/len(scores)
count=0
for s in scores:
    if s>average:
        count+=1
print("total score:",total)
print("average score:",average)
print("scores above average:",count)
# Out:
# total score: 368
# average score: 73.6
# scores above average: 3

# %%
#product price lock system
prices=(100,200,300)
print(prices[1])
# Out:
# 200

# %%
#feedback tracker
feedback={"positive":45, "neutral":18, "negative":7}
total=sum(feedback.values())
highest=max(feedback,key=feedback.get)
print("total feedback",total)
print("highest feedback type:",highest)
# Out:
# total feedback 70
# highest feedback type: positive
